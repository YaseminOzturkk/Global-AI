# %% [markdown]
# <a href="https://colab.research.google.com/github/YaseminOzturkk/Global-AI-Summer-Camp-22/blob/main/Introduction_to_Python_Exercise2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Practical exercise 2:  You are a game developer :)
#
# In this practical exercise you are a game developer. You will program your first game – Rock, Paper, Scissors.
#
# If you are not familiar with the game, you can read about it here: https://en.wikipedia.org/wiki/Rock_paper_scissors.
#
# You will program the game step by step. Please read the instructions carefully. There are hints and important explanations that will help you with this exercise.

# %% [markdown]
# ##Warm up
#
# Each player can choose between the three actions "rock", "paper" and "scissors". First, you need to create a list that contains all possible actions.

# %%
#Please create a list containing the three actions of the game.

action_list = ['rock', 'paper','scissors']
action_list
# Out:
# ['rock', 'paper', 'scissors']

# %% [markdown]
# # Choose an action
#
# Now you have the list with the actions ready. The next step is to let Python randomly choose an action from this list. Each player has to make a choice, so Python has to make a choice for player 1 and another one for player 2.
#
# 📌The built-in module "random" can help you with this. As you might remember from previous lessons you can use the .randint() method to generate random numbers.
#
# 📌📌There is another method in the random module called .choice(). It takes a list as input and selects an item randomly from that list.

# %%
#Import the random library

import random
#Select a random action for each player

yase_choice = random.choice(action_list)
tubi_choice = action_list[random.randint(0,2)]

#Use the print function to print the players choices
print(yase_choice)
print(tubi_choice)
# Out:
# scissors
# paper

# %% [markdown]
# # Determine the winner
#
# So, who won? To determine the winner, you first have to specify all possible outcomes of the game. Then you can use conditional statements to specify which outcome will lead to a win for player 1 or player 2, or a tie.
#
# First, let's start with the outcome that both users chose the same action: a tie!
# In case of a tie, the game should print the message "Tie! Both players chose the same action." to the screen.
#
# 📌Use conditional statements to check whether the players actions are equal to each other and *if* this condition is true the message should be printed.

# %%
#1 - Tie Condition
#Please write an if statement to check if the players chose the same action
import time
if tubi_choice == yase_choice:
  print('Tie! Both players chose the same action.')

else:
  print('The winner will be determined now!')
  time.sleep(2)
# Out:
# The winner will be determined now!

# %% [markdown]
# Now, let's focus on the remaining outcomes. We have three different actions: rock, paper and scissors.
#
# This is a list of all the possible combinations (without those that result in a tie):
#
# 1.   (paper, rock)
# 2.   (paper, scissors)
# 3.   (scissors, rock)
# 4.   (scissors, paper)
# 5.   (rock, paper)
# 6.   (rock, scissors)
#
# You need to check all these conditions in order to determine the winner.
#
# 📌You can use the "and" operator to combine two actions in one conditional statement.
#
# 📌📌Another approach is using nested if statements to check whether the action of player 2 beats the action of player 1.
#
# 🧨💣In the cell, first copy the code you wrote for "Tie" conditions. Then continue to add the other outcomes using "elif".

# %%
#Copy your code of the tie-conditions here
#1 - Tie Condition

if tubi_choice == yase_choice:
  print('Tie! Both players chose the same action.')

#2-Winning Conditions
#Please add the conditional statements for the remaining combinations 

elif tubi_choice == 'paper' and yase_choice == 'rock':
  print('Winner is: Tuğba!')

elif tubi_choice == 'paper' and yase_choice == 'scissors':
  print('Winner is: Yasemin!')

elif tubi_choice == 'scissors' and yase_choice == 'rock':
  print('Winner is: Yasemin!')

elif tubi_choice == 'scissors' and yase_choice == 'paper':
  print('Winner is: Tuğba!')

elif tubi_choice == 'rock' and yase_choice == 'paper':
  print('Winner is: Yasemin!')


elif tubi_choice == 'rock' and yase_choice == 'scissors':
  print('Winner is: Tuğba!')
# Out:
# Winner is: Yasemin!

# %% [markdown]
# # Best of 3 or 5 or single round ? :)
#
# Now that you have your game set, let's also ask the users how many rounds they want to play.
#
# 📌 You can use the input function for this.
#
# And because there are multiple rounds, you need to keep track of the score. For this, you need to create a variable for each player that is 0 in the beginning.

# %%
#Please ask the user how many rounds they want to play

total_round = input('Can you specify how many rounds you will play?')
#Scores of players

tubi = 0
yase = 0
# Out:
# Can you specify how many rounds you will play?5

# %% [markdown]
# # Use a for loop to specify the number of rounds
# The user specified how many rounds he or she wants to play.
#
# One way to use this information is to put the game inside of a for loop.
#
# 📌 You can use a for loop and the range() function to repeat the loop for a specified number of times.
#
# 📌📌 Don't forget to convert the user input to the data type integer. You can use the int() function for this.
#
# 📌📌📌 Don't forget to increment or add 1 to the score of the players that win, and print the current score after each round. You can use the assignment operator +=1 for this.

# %%
#Collect all the components of your program to run it in a for loop
#Import the random library
import random

#Add the code to create a list containing the three actions of the game.
action_list = ['rock', 'paper', 'scissors']

#Add the code to set the scores of players to 0
tubi = 0
yase = 0

#Add the code to ask the user how many rounds they want to play

total_round = input('Can you specify how many rounds you will play?")
#Write a for loop and put the game inside

for i in range(int(total_round)):


  #Add the code to select a random action for each player
  yase_choice = random.choice(action_list)
  tubi_choise = action_list[random.randint(0,2)]

  #Add the code to print the players choices
  print(yase_choice)
  print(tubi_choice)

  #Add the tie condition
  if yase_choice == tubi_choice:
    print('Tie! Both players chose the same action.')

  #Add the remaining condition

  elif tubi_choice == 'paper' and yase_choice == 'rock':
    print('Winner is: Tuğba!')

  elif tubi_choice == 'paper' and yase_choice == 'scissors':
    print('Winner is: Yasemin!')

  elif tubi_choice == 'scissors' and yase_choice == 'rock':
    print('Winner is: Yasemin!')

  elif tubi_choice == 'scissors' and yase_choice == 'paper':
    print('Winner is: Tuğba!')

  elif tubi_choice == 'rock' and yase_choice == 'paper':
    print('Winner is: Yasemin!')


  elif tubi_choice == 'rock' and yase_choice == 'scissors':
    print('Winner is: Tuğba!')

  #print the score

# %%
#Collect all the components of your program to run it in a for loop
#Import the random library
import random

#Add the code to create a list containing the three actions of the game.
action_list = ['rock', 'paper', 'scissors']

#Add the code to set the scores of players to 0
tubi_score = 0
yase_score = 0

#Add the code to ask the user how many rounds they want to play
total_round = input("How many rounds do you want to play? ")

#Write a for loop and put the game inside
for i in range(int(total_round)):

  #Add the code to select a random action for each player
  tubi_choice = random.choice(action_list)
  yase_choice = action_list[random.randint(0,2)]

  #Add the code to print the players choices
  print("Tuğba:", tubi_choice)
  print("Yasemin:", yase_choice)

  #Add the tie condition
  if tubi_choice == yase_choice:
    print("Tie! Both player chose same action.")

  #Add the remaining condition
  elif tubi_choice == 'paper':
    if yase_choice == 'rock':
      print("Winner is: Tuğba")
      tubi_score +=1
    else:
      print("Winner is: Yasemin")
      yase_score +=1

  elif tubi_choice == 'rock':
    if yase_choice == 'paper':
      print("Winner is: Yassemin")
      yase_score +=1
    else:
      print("Winner is: Tuğba")
      tubi_score +=1

  elif tubi_choice == 'scissors':
    if yase_choice == 'paper':
      print("Winner is: Tuğba")
      tubi_score +=1
    else:
      print("Winner is: Yasemin")
      yase_score +=1

  #print the score
  print("Score:", "Tuğba =",tubi_score, "Yasemin =",yase_score)
# Out:
# How many rounds do you want to play? 7
# Tuğba: scissors
# Yasemin: rock
# Winner is: Yasemin
# Score: Tuğba = 0 Yasemin = 1
# Tuğba: paper
# Yasemin: rock
# Winner is: Tuğba
# Score: Tuğba = 1 Yasemin = 1
# Tuğba: rock
# Yasemin: paper
# Winner is: Yassemin
# Score: Tuğba = 1 Yasemin = 2
# Tuğba: scissors
# Yasemin: paper
# Winner is: Tuğba
# Score: Tuğba = 2 Yasemin = 2
# Tuğba: scissors
# Yasemin: scissors
# Tie! Both player chose same action.
# Score: Tuğba = 2 Yasemin = 2
# Tuğba: paper
# Yasemin: paper
# Tie! Both player chose same action.
# Score: Tuğba = 2 Yasemin = 2
# Tuğba: scissors
# Yasemin: scissors
# Tie! Both player chose same action.
# Score: Tuğba = 2 Yasemin = 2

# %% [markdown]
# # Use a while loop to specify the number of rounds - Part 1
#
# In this module we also learned about while loops. Another way to play the game over and over again is using a while loop.
#
# This time, let's put the game inside a while loop.
#
# 📌 You can directly use the value *True* to specify that the while loop should be executed.
#
# 💣 By the way: Another very common name for True/False values is "**Boolean values**" or "**Bools**" in short.
#
# 🧨🧨 Caution! Since we run the game in an while loop, you have to stop the game manually. Otherwise it will run infinitely.

# %%
#Collect all the components of your program to run it in a while loop
#Import the random library
import random

#Add the code to create a list containing the three actions of the game.
action_list = ['rock', 'paper', 'scissors']

#Add the code to set the scores of players to 0
tubi_score = 0
yase_score = 0

#Write a while loop and put the game inside
while True:

  #Add the code to select a random action for each player
  tubi_choice = random.choice(action_list)
  yase_choice = action_list[random.randint(0,2)]

  #Add the code to print the players choices
  print("Tuğba:", tubi_choice)
  print("Yasemin:", yase_choice)

  #Add the tie condition
  if tubi_choice == yase_choice:
    print("Tie! Both player chose same action.")

  #Add the remaining condition
  elif tubi_choice == 'paper':
    if yase_choice == 'rock':
      print("Winner is: Tuğba")
      tubi_score +=1
    else:
      print("Winner is: Yasemin")
      yase_score +=1

  elif tubi_choice == 'rock':
    if yase_choice == 'paper':
      print("Winner is: Yasemin")
      yase_score +=1
    else:
      print("Winner is: Tuğba")
      tubi_score +=1

  elif tubi_choice == 'scissors':
    if yase_choice == 'paper':
      print("Winner is: Tuğba")
      tubi_score +=1
    else:
      print("Winner is: Yasemin")
      yase_score +=1

  #print the score
  print("Score:", "Tuğba =",tubi_score, "Yasemin =",yase_score)
  break
# Out:
# Görüntülenen çıkış son 5000 satıra kısaltıldı.
# Tie! Both player chose same action.
# Score: Tuğba = 9029 Yasemin = 9045
# Tuğba: scissors
# Yasemin: rock
# Winner is: Yasemin
# Score: Tuğba = 9029 Yasemin = 9046
# Tuğba: paper
# Yasemin: scissors
# Winner is: Yasemin
# Score: Tuğba = 9029 Yasemin = 9047
# Tuğba: paper
# Yasemin: scissors
# Winner is: Yasemin
# Score: Tuğba = 9029 Yasemin = 9048
# Tuğba: rock
# Yasemin: rock
# Tie! Both player chose same action.
# Score: Tuğba = 9029 Yasemin = 9048
# Tuğba: scissors
# Yasemin: rock
# Winner is: Yasemin
# Score: Tuğba = 9029 Yasemin = 9049
# Tuğba: paper
# Yasemin: rock
# Winner is: Tuğba
# Score: Tuğba = 9030 Yasemin = 9049
# Tuğba: paper
# Yasemin: scissors
# Winner is: Yasemin
# Score: Tuğba = 9030 Yasemin = 9050
# Tuğba: rock
# Yasemin: scissors
# Winner is: Tuğba
# Score: Tuğba = 9031 Yasemin = 9050
# Tuğba: paper
# Yasemin: scissors
# Winner is: Yasemin
# Score: Tuğba = 9031 Yasemin = 9051
# Tuğba: rock
# Yasemin: paper
# Winner is: Yasemin
# Score: Tuğba = 9031 Yasemin = 9052
# Tuğba: scissors
# Yasemin: rock
# Winner is: Yasemin
# Score: Tuğba = 9031 Yasemin = 9053
# Tuğba: rock
# Yasemin: paper
# Winner is: Yasemin
# Score: Tuğba = 9031 Yasemin = 9054
# Tuğba: scissors
# Yasemin: scissors
# Tie! Both player chose same action.
# Score: Tuğba = 9031 Yasemin = 9054
# Tuğba: paper
# Yasemin: scissors
# Winner is: Yasemin
# Score: Tuğba = 9031 Yasemin = 9055
# Tuğba: rock
# Yasemin: scissors
# Winner is: Tuğba
# Score: Tuğba = 9032 Yasemin = 9055
# Tuğba: paper
# Yasemin: scissors
# Winner is: Yasemin
# Score: Tuğba = 9032 Yasemin = 9056
# Tuğba: paper
# Yasemin: rock
# Winner is: Tuğba
# Score: Tuğba = 9033 Yasemin = 9056
# Tuğba: rock
# Yasemin: scissors
# Winner is: Tuğba
# Score: Tuğba = 9034 Yasemin = 9056
# Tuğba: paper
# Yasemin: scissors
# Winner is: Yasemin
# Score: Tuğba = 9034 Yasemin = 9057
# Tuğba: rock
# Yasemin: paper
# Winner is: Yasemin
# Score: Tuğba = 9034 Yasemin = 9058
# Tuğba: paper
# Yasemin: paper
# Tie! Both player chose same action.
# Score: Tuğba = 9034 Yasemin = 9058
# Tuğba: scissors
# Yasemin: paper
# Winner is: Tuğba
# Score: Tuğba = 9035 Yasemin = 9058
# Tuğba: paper
# Yasemin: scissors
# Winner is: Yasemin
# Score: Tuğba = 9035 Yasemin = 9059
# Tuğba: scissors
# Yasemin: paper
# Winner is: Tuğba
# Score: Tuğba = 9036 Yasemin = 9059
# Tuğba: scissors
# Yasemin: rock
# Winner is: Yasemin
# Score: Tuğba = 9036 Yasemin = 9060
# Tuğba: paper
# Yasemin: rock
# Winner is: Tuğba
# Score: Tuğba = 9037 Yasemin = 9060
# Tuğba: paper
# Yasemin: scissors
# Winner is: Yasemin
# Score: Tuğba = 9037 Yasemin = 9061
# Tuğba: scissors
# Yasemin: scissors
# Tie! Both player chose same action.
# Score: Tuğba = 9037 Yasemin = 9061
# Tuğba: paper
# Yasemin: rock
# Winner is: Tuğba
# Score: Tuğba = 9038 Yasemin = 9061
# Tuğba: rock
# Yasemin: scissors
# Winner is: Tuğba
# Score: Tuğba = 9039 Yasemin = 9061
# Tuğba: paper
# Yasemin: rock
# Winner is: Tuğba
# Score: Tuğba = 9040 Yasemin = 9061
# Tuğba: scissors
# Yasemin: rock
# Winner is: Yasemin
# Score: Tuğba = 9040 Yasemin = 9062
# Tuğba: paper
# Yasemin: rock
# Winner is: Tuğba
# Score: Tuğba = 9041 Yasemin = 9062
# Tuğba: paper
# Yasemin: paper
# Tie! Both player chose same action.
# Score: Tuğba = 9041 Yasemin = 9062
# Tuğba: rock
# Yasemin: scissors
# Winner is: Tuğba
# Score: Tuğba = 9042 Yasemin = 9062
# Tuğba: rock
# Yasemin: rock
# Tie! Both player chose same action.
# Score: Tuğba = 9042 Yasemin = 9062
# Tuğba: scissors
# Yasemin: rock
# Winner is: Yasemin
# Score: Tuğba = 9042 Yasemin = 9063
# Tuğba: rock
# Yasemin: scissors
# Winner is: Tuğba
# Score: Tuğba = 9043 Yasemin = 9063
# Tuğba: paper
# Yasemin: scissors
# Winner is: Yasemin
# Score: Tuğba = 9043 Yasemin = 9064
# Tuğba: scissors
# Yasemin: paper
# Winner is: Tuğba
# Score: Tuğba = 9044 Yasemin = 9064
# Tuğba: scissors
# Yasemin: paper
# Winner is: Tuğba
# Score: Tuğba = 9045 Yasemin = 9064
# Tuğba: paper
# Yasemin: rock
# Winner is: Tuğba
# Score: Tuğba = 9046 Yasemin = 9064
# Tuğba: paper
# Yasemin: rock
# Winner is: Tuğba
# Score: Tuğba = 9047 Yasemin = 9064
# Tuğba: paper
# Yasemin: paper
# Tie! Both player chose same action.
# Score: Tuğba = 9047 Yasemin = 9064
# Tuğba: rock
# Yasemin: scissors
# Winner is: Tuğba
# Score: Tuğba = 9048 Yasemin = 9064
# Tuğba: rock
# Yasemin: rock
# Tie! Both player chose same action.
# Score: Tuğba = 9048 Yasemin = 9064
# Tuğba: scissors
# Yasemin: rock
# Winner is: Yasemin
# Score: Tuğba = 9048 Yasemin = 9065
# Tuğba: rock
# Yasemin: scissors
# Winner is: Tuğba
# Score: Tuğba = 9049 Yasemin = 9065
# Tuğba: paper
# Yasemin: scissors
# Winner is: Yasemin
# Score: Tuğba = 9049 Yasemin = 9066
# Tuğba: paper
# Yasemin: rock
# Winner is: Tuğba
# Score: Tuğba = 9050 Yasemin = 9066
# Tuğba: rock
# Yasemin: paper
# Winner is: Yasemin
# Score: Tuğba = 9050 Yasemin = 9067
# Tuğba: rock
# Yasemin: scissors
# Winner is: Tuğba
# Score: Tuğba = 9051 Yasemin = 9067
# Tuğba: paper
# Yasemin: paper
# Tie! Both player chose same action.
# Score: Tuğba = 9051 Yasemin = 9067
# Tuğba: scissors
# Yasemin: paper
# Winner is: Tuğba
# Score: Tuğba = 9052 Yasemin = 9067
# Tuğba: scissors
# Yasemin: paper
# Winner is: Tuğba
# Score: Tuğba = 9053 Yasemin = 9067
# Tuğba: scissors
# Yasemin: paper
# Winner is: Tuğba
# Score: Tuğba = 9054 Yasemin = 9067
# Tuğba: paper
# Yasemin: rock
# Winner is: Tuğba
# Score: Tuğba = 9055 Yasemin = 9067
# Tuğba: rock
# Yasemin: rock
# Tie! Both player chose same action.
# Score: Tuğba = 9055 Yasemin = 9067
# Tuğba: scissors
# Yasemin: paper
# Winner is: Tuğba
# Score: Tuğba = 9056 Yasemin = 9067
# Tuğba: paper
# Yasemin: rock
# Winner is: Tuğba
# Score: Tuğba = 9057 Yasemin = 9067
# Tuğba: scissors
# Yasemin: scissors
# Tie! Both player chose same action.
# Score: Tuğba = 9057 Yasemin = 9067
# Tuğba: scissors
# Yasemin: paper
# Winner is: Tuğba
# Score: Tuğba = 9058 Yasemin = 9067
# Tuğba: scissors
# Yasemin: rock
# Winner is: Yasemin
# Score: Tuğba = 9058 Yasemin = 9068
# Tuğba: paper
# Yasemin: paper
# Tie! Both player chose same action.
# Score: Tuğba = 9058 Yasemin = 9068
# Tuğba: rock
# Yasemin: rock
# Tie! Both player chose same action.
# Score: Tuğba = 9058 Yasemin = 9068
# Tuğba: paper
# Yasemin: scissors
# Winner is: Yasemin
# Score: Tuğba = 9058 Yasemin = 9069
# Tuğba: scissors
# Yasemin: scissors
# Tie! Both player chose same action.
# Score: Tuğba = 
# Tuğba: rock
# Yasemin: paper
# Winner is: Yasemin
# Score: Tuğba = 9449 Yasemin = 9431
# Tuğba: rock
# Yasemin: paper
# Winner is: Yasemin
# Score: Tuğba = 9449 Yasemin = 9432
# Tuğba: paper
# Yasemin: scissors
# Winner is: Yasemin
# Score: Tuğba = 9449 Yasemin = 9433
# Tuğba: paper
# Yasemin: scissors
# Winner is: Yasemin
# Score: Tuğba = 9449 Yasemin = 9434
# Tuğba: paper
# Yasemin: paper
# Tie! Both player chose same action.
# Score: Tuğba = 9449 Yasemin = 9434
# Tuğba: scissors
# Yasemin: paper
# Winner is: Tuğba
# Score: Tuğba = 9450 Yasemin = 9434
# Tuğba: paper
# Yasemin: scissors
# Winner is: Yasemin
# Score: Tuğba = 9450 Yasemin = 9435
# Tuğba: rock
# Yasemin: rock
# Tie! Both player chose same action.
# Score: Tuğba = 9450 Yasemin = 9435
# Tuğba: paper
# Yasemin: paper
# Tie! Both player chose same action.
# Score: Tuğba = 9450 Yasemin = 9435
# Tuğba: rock
# Yasemin: scissors
# Winner is: Tuğba
# Score: Tuğba = 9451 Yasemin = 9435
# Tuğba: scissors
# Yasemin: paper
# Winner is: Tuğba
# Score: Tuğba = 9452 Yasemin = 9435
# Tuğba: paper
# Yasemin: scissors
# Winner is: Yasemin
# Score: Tuğba = 9452 Yasemin = 9436
# Tuğba: scissors
# Yasemin: rock
# Winner is: Yasemin
# Score: Tuğba = 9452 Yasemin = 9437
# Tuğba: scissors
# Yasemin: paper
# Winner is: Tuğba
# Score: Tuğba = 9453 Yasemin = 9437
# Tuğba: rock
# Yasemin: paper
# Winner is: Yasemin
# Score: Tuğba = 9453 Yasemin = 9438
# Tuğba: rock
# Yasemin: rock
# Tie! Both player chose same action.
# Score: Tuğba = 9453 Yasemin = 9438
# Tuğba: scissors
# Yasemin: rock
# Winner is: Yasemin
# Score: Tuğba = 9453 Yasemin = 9439
# Tuğba: scissors
# Yasemin: rock
# Winner is: Yasemin
# Score: Tuğba = 9453 Yasemin = 9440
# Tuğba: paper
# Yasemin: paper
# Tie! Both player chose same action.
# Score: Tuğba = 9453 Yasemin = 9440
# Tuğba: scissors
# Yasemin: scissors
# Tie! Both player chose same action.
# Score: Tuğba = 9453 Yasemin = 9440
# Tuğba: scissors
# Yasemin: scissors
# Tie! Both player chose same action.
# Score: Tuğba = 9453 Yasemin = 9440
# Tuğba: scissors
# Yasemin: rock
# Winner is: Yasemin
# Score: Tuğba = 9453 Yasemin = 9441
# Tuğba: scissors
# Yasemin: rock
# Winner is: Yasemin
# Score: Tuğba = 9453 Yasemin = 9442
# Tuğba: paper
# Yasemin: rock
# Winner is: Tuğba
# Score: Tuğba = 9454 Yasemin = 9442
# Tuğba: paper
# Yasemin: scissors
# Winner is: Yasemin
# Score: Tuğba = 9454 Yasemin = 9443
# Tuğba: scissors
# Yasemin: scissors
# Tie! Both player chose same action.
# Score: Tuğba = 9454 Yasemin = 9443
# Tuğba: rock
# Yasemin: rock
# Tie! Both player chose same action.
# Score: Tuğba = 9454 Yasemin = 9443
# Tuğba: paper
# Yasemin: paper
# Tie! Both player chose same action.
# Score: Tuğba = 9454 Yasemin = 9443
# Tuğba: paper
# Yasemin: scissors
# Winner is: Yasemin
# Score: Tuğba = 9454 Yasemin = 9444
# Tuğba: paper
# Yasemin: paper
# Tie! Both player chose same action.
# Score: Tuğba = 9454 Yasemin = 9444
# Tuğba: rock
# Yasemin: scissors
# Winner is: Tuğba
# Score: Tuğba = 9455 Yasemin = 9444
# Tuğba: rock
# Yasemin: paper
# Winner is: Yasemin
# Score: Tuğba = 9455 Yasemin = 9445
# Tuğba: scissors
# Yasemin: rock
# Winner is: Yasemin
# Score: Tuğba = 9455 Yasemin = 9446
# Tuğba: paper
# Yasemin: paper
# Tie! Both player chose same action.
# Score: Tuğba = 9455 Yasemin = 9446
# Tuğba: scissors
# Yasemin: rock
# Winner is: Yasemin
# Score: Tuğba = 9455 Yasemin = 9447
# Tuğba: scissors
# Yasemin: paper
# Winner is: Tuğba
# Score: Tuğba = 9456 Yasemin = 9447
# Tuğba: paper
# Yasemin: scissors
# Winner is: Yasemin
# Score: Tuğba = 9456 Yasemin = 9448
# Tuğba: paper
# Yasemin: paper
# Tie! Both player chose same action.
# Score: Tuğba = 9456 Yasemin = 9448
# Tuğba: scissors
# Yasemin: rock
# Winner is: Yasemin
# Score: Tuğba = 9456 Yasemin = 9449
# Tuğba: rock
# Yasemin: rock
# Tie! Both player chose same action.
# Score: Tuğba = 9456 Yasemin = 9449
# Tuğba: scissors
# Yasemin: rock
# Winner is: Yasemin
# Score: Tuğba = 9456 Yasemin = 9450
# Tuğba: scissors
# Yasemin: paper
# Winner is: Tuğba
# Score: Tuğba = 9457 Yasemin = 9450
# Tuğba: paper
# Yasemin: paper
# Tie! Both player chose same action.
# Score: Tuğba = 9457 Yasemin = 9450
# Tuğba: scissors
# Yasemin: rock
# Winner is: Yasemin
# Score: Tuğba = 9457 Yasemin = 9451
# Tuğba: rock
# Yasemin: paper
# Winner is: Yasemin
# Score: Tuğba = 9457 Yasemin = 9452
# Tuğba: paper
# Yasemin: scissors
# Winner is: Yasemin
# Score: Tuğba = 9457 Yasemin = 9453
# Tuğba: rock
# Yasemin: rock
# Tie! Both player chose same action.
# Score: Tuğba = 9457 Yasemin = 9453
# Tuğba: scissors
# Yasemin: rock
# Winner is: Yasemin
# Score: Tuğba = 9457 Yasemin = 9454
# Tuğba: scissors
# Yasemin: paper
# Winner is: Tuğba
# Score: Tuğba = 9458 Yasemin = 9454
# Tuğba: rock
# Yasemin: scissors
# Winner is: Tuğba
# Score: Tuğba = 9459 Yasemin = 9454
# Tuğba: paper
# Yasemin: rock
# Winner is: Tuğba
# Score: Tuğba = 9460 Yasemin = 9454
# Tuğba: scissors
# Yasemin: scissors
# Tie! Both player chose same action.
# Score: Tuğba = 9460 Yasemin = 9454
# Tuğba: rock
# Yasemin: rock
# Tie! Both player chose same action.
# Score: Tuğba = 9460 Yasemin = 9454
# Tuğba: scissors
# Yasemin: scissors
# Tie! Both player chose same action.
# Score: Tuğba = 9460 Yasemin = 9454
# Tuğba: paper
# Yasemin: paper
# Tie! Both player chose same action.
# Score: Tuğba = 9460 Yasemin = 9454
# Tuğba: rock
# Yasemin: rock
# Tie! Both player chose same action.
# Score: Tuğba = 9460 Yasemin = 9454
# Tuğba: paper
# Yasemin: paper
# Tie! Both player chose same action.
# Score: Tuğba = 9460 Yasemin = 9454
# Tuğba: scissors
# Yasemin: scissors
# Tie! Both player chose same action.
# Score: Tuğba = 9460 Yasemin = 9454
# Tuğba: paper
# Yasemin: paper
# Tie! Both player chose same action.
# Score: Tuğba = 9460 Yasemin = 9454
# Tuğba: scissors
# Yasemin: rock
# Winner is: Yasemin
# Score: Tuğba = 9460 Yasemin = 9455
# Tuğba: rock
# Yasemin: scissors
# Winner is: Tuğba
# Score: Tuğba = 9461 Yasemin = 9455
# Tuğba: scissors
# Yasemin: rock
# Winner is: Yasemin
# Score: Tuğba = 9461 Yasemin = 9456
# Tuğba: rock
# Yasemin: paper
# Winner is: Yasemin
# Score: Tuğba = 9461 Yasemin = 9457
# Tuğba: rock
# Yasemin: paper
# Winner is: Yasemin
# Score: Tuğba = 9461 Yasemin = 9458
# Tuğba: rock
# Yasemin: scissors
# Winner is: Tuğba
# Score: Tuğba = 9462 Yasemin = 9458
# Tuğba: scissors
# Yasemin: scissors
# Tie! Both player chose same action.
# Score: Tuğba = 9462 Yasemin = 9458
# Tuğba: paper
# Yasemin: rock
# Winner is: Tuğba
# Score: Tuğba = 9463 Yasemin = 9458
# Tuğba: rock
# Yasemin: paper
# Winner is: Yasemin
# Score: Tuğba = 9463 Yasemin = 9459
# Tuğba: scissors
# Yasemin: paper
# Winner is: Tuğba
# Score: Tuğba = 9464 Yasemin = 9459
# Tuğba: scissors
# Yasemin: scissors
# Tie! Both player chose same action.
# Score: Tuğba = 9464 Yasemin = 9459
# Tuğba:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-21-0ee4ef11f887> in <module>()
#      18
#      19   #Add the code to print the players choices
# ---> 20   print("Tuğba:", tubi_choice)
#      21   print("Yasemin:", yase_choice)
#      22
#
# /usr/local/lib/python3.7/dist-packages/ipykernel/iostream.py in write(self, string)
#     398             is_child = (not self._is_master_process())
#     399             # only touch the buffer in the IO thread to avoid races
# --> 400             self.pub_thread.schedule(lambda : self._buffer.write(string))
#     401             if is_child:
#     402                 # newlines imply flush in subprocesses
#
# /usr/local/lib/python3.7/dist-packages/ipykernel/iostream.py in schedule(self, f)
#     201             self._events.append(f)
#     202             # wake event thread (message content is ignored)
# --> 203             self._event_pipe.send(b'')
#     204         else:
#     205             f()
#
# /usr/local/lib/python3.7/dist-packages/zmq/sugar/socket.py in send(self, data, flags, copy, track, routing_id, group)
#     616                 )
#     617             data.group = group
# --> 618         return super().send(data, flags=flags, copy=copy, track=track)
#     619
#     620     def send_multipart(
#
# zmq/backend/cython/socket.pyx in zmq.backend.cython.socket.Socket.send()
#
# zmq/backend/cython/socket.pyx in zmq.backend.cython.socket.Socket.send()
#
# zmq/backend/cython/socket.pyx in zmq.backend.cython.socket._send_copy()
#
# /usr/local/lib/python3.7/dist-packages/zmq/backend/cython/checkrc.pxd in zmq.backend.cython.checkrc._check_rc()
#
# KeyboardInterrupt:

# %% [markdown]
# # Use a while loop to specify the number of rounds - Part 2
#
# Now the game runs infinitely and the user can end it manually. But there is a more efficient way to do this: Let's ask the user again how many rounds they want to play, just as you did for the game inside the for loop.
#
# To prevent an infinite loop, you need to add a round_counter that is 0 at the beginning. In each round, this counter needs to increase by 1.
#
# At the end of your while loop, you need to add an "if" condition to check whether the round_counter is equal to the number of rounds that we got from user as an input. If this is the case, we need to use "**break**" to end the game.
#
# Once we end the game, it would be nice to see a message that prints the winner to the screen. In case of a tie, it should print a message that the game ended in a tie.
#
# 📌 You can use "if" and "elif" statements to determine the winner at the end.

# %%
#Collect all the components of your program to run it in a while loop
#Import the random library
Import random

#Add the code to create a list containing the three actions of the game.

action_list = ['rock', 'paper', 'scissors']
#Add the code to set the scores of players to 0
tubi_score = 0
yase_score = 0
#Add a round_counter that is 0 at the beginning
round_counter = 0

#Add the code to ask the user how many rounds they want to play
total_round = input('How many rounds do you want to play?')

#Write a while loop and put the game inside

while True:
  #increase round_counter by 1 and print it
  round_counter += 1
  print('Round number:', round_counter)
  #Add the code to select a random action for each player
  tubi_choice = random.random.choice(action_list)
  yase_choice = action_list(random.randint[0,2])

  #Add the code to print the players choices
  print('Tuğba:', tubi_choise)
  print('Yasemin:', yase_choice)

  #Add the tie condition
  if tubi_choise == yase_choice:
    print("Tie! Both player chose same action.")

  #Add the remaining condition
  elif tubi_choice == 'paper':
    if yase_choice == 'rock':
      print("Winner is: Tuğba")
      tubi_score +=1
    else:
      print("Winner is: Yasemin")
      yase_score +=1

  elif tubi_choice == 'rock':
    if yase_choice == 'paper':
      print("Winner is: Yasemin")
      yase_score +=1
    else:
      print("Winner is: Tuğba")
      tubi_score +=1

  elif tubi_choice == 'scissors':
    if yase_choice == 'paper':
      print("Winner is: Tuğba")
      tubi_score +=1
    else:
      print("Winner is: Yasemin")
      yase_score +=1

  #print the score

  print('"Score:", "Tuğba =",tubi_score, "Yasemin =",yase_score)
  #stop the while loop if the round_counter equals the number of total rounds

  if rount_counter == int(total_round)
  break
#Print the outcome of the game by using conditional statements

  if tubi_score == yase_score:
    print("There is no winner, tie.")
  
  elif tubi_score > yase_score
    print("

# %%
#Collect all the components of your program to run it in a while loop
#Import the random library
import random

#Add the code to create a list containing the three actions of the game.
action_list = ['rock', 'paper', 'scissors']

#Add the code to set the scores of players to 0
tubi_score = 0
yase_score = 0
#Add a round_counter that is 0 at the beginning
round_counter = 0

#Add the code to ask the user how many rounds they want to play
total_round = input("How many rounds do you want to play? ")

#Write a while loop and put the game inside
while True:

  #increase round_counter by 1 and print it
  round_counter +=1
  print("Round number:", round_counter)

  #Add the code to select a random action for each player
  tubi_choice = random.choice(action_list)
  yase_choice = action_list[random.randint(0,2)]

  #Add the code to print the players choices
  print("Tuğba:", tubi_choice)
  print("Yasemin:", yase_choice)

  #Add the tie condition
  if tubi_choice == yase_choice:
    print("Tie! Both player chose same action.")

  #Add the remaining condition
  elif tubi_choice == 'paper':
    if yase_choice == 'rock':
      print("Winner is: Tuğba")
      tubi_score +=1
    else:
      print("Winner is: Yasemin")
      yase_score +=1

  elif tubi_choice == 'rock':
    if yase_choice == 'paper':
      print("Winner is: Yasemin")
      yase_score +=1
    else:
      print("Winner is: Tuğba")
      tubi_score +=1

  elif tubi_choice == 'scissors':
    if yase_choice == 'paper':
      print("Winner is: Tuğba")
      tubi_score +=1
    else:
      print("Winner is: Yasemin")
      yase_score +=1

  #print the score
  print("Score:", "Tuğba =",tubi_score, "Yasemin =",yase_score)

  #stop the while loop if the round_counter equals the number of total rounds
  if round_counter == int(total_round):
    break
#Print the outcome of the game by using conditional statements
if tubi_score == yase_score:
  print("There is no winner, tie.")
elif tubi_score > yase_score:
  print("Tuğba won with score", tubi_score, ":", yase_score)
elif tubi_score < yase_score:
  print("Player 2 won with score", tubi_score, ":", yase_score)
# Out:
# How many rounds do you want to play? 3
# Round number: 1
# Tuğba: rock
# Yasemin: scissors
# Winner is: Tuğba
# Score: Tuğba = 1 Yasemin = 0
# Round number: 2
# Tuğba: scissors
# Yasemin: rock
# Winner is: Yasemin
# Score: Tuğba = 1 Yasemin = 1
# Round number: 3
# Tuğba: paper
# Yasemin: rock
# Winner is: Tuğba
# Score: Tuğba = 2 Yasemin = 1
# Tuğba won with score 2 : 1
